# %% [markdown]
# <a href="https://colab.research.google.com/github/CYJienn/Introduction-to-Python/blob/main/Tutorial_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Part 1-Google Colab,Kaggle and GitHub

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data.csv')

df.head()
# Out:
# Mounted at /content/drive
#     1st   2nd   3rd   4th   5th  College Code  Gender  Roll  Roll no.  \
# 0  8.11  7.68  7.11  7.43  8.18           115  Female   NaN   17020.0
# 1  6.48  5.90  4.15  4.29  4.96           115    Male   NaN   17021.0
# 2  8.41  8.24  7.52  8.25  7.75           115  Female   NaN   17022.0
# 3  7.33  6.83  6.33  6.79  6.89           115    Male   NaN   17023.0
# 4  7.89  7.34  7.22  7.32  7.46           115    Male   NaN   17024.0
#
#    Subject Code
# 0            16
# 1            16
# 2            16
# 3            16
# 4            16

# %%
import pandas as pd

df = pd.read_csv('data.csv')

df.head()
# Out:
#     1st   2nd   3rd   4th   5th  College Code  Gender  Roll  Roll no.  \
# 0  8.11  7.68  7.11  7.43  8.18           115  Female   NaN   17020.0
# 1  6.48  5.90  4.15  4.29  4.96           115    Male   NaN   17021.0
# 2  8.41  8.24  7.52  8.25  7.75           115  Female   NaN   17022.0
# 3  7.33  6.83  6.33  6.79  6.89           115    Male   NaN   17023.0
# 4  7.89  7.34  7.22  7.32  7.46           115    Male   NaN   17024.0
#
#    Subject Code
# 0            16
# 1            16
# 2            16
# 3            16
# 4            16
